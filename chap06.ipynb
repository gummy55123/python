# %% [markdown]
# # Chap6
# # os套件：用來處理文件與目錄，與檔案相關操作

# %%
import os
print(os.getcwd()) #顯示目前所在的工作目錄
# Out:
# /home/jovyan/demo

# %%
#顯示目錄下的檔案
os.listdir(".")
# Out:
# ['TCGA_Data',
#  'jupyterlab-slides.pdf',
#  'data',
#  'jupyterlab.md',
#  'lorenz.py',
#  'big.csv',
#  'Lorenz.ipynb',
#  'markdown_python.md',
#  'notebooks',
#  'Untitled1.ipynb',
#  'Untitled.ipynb',
#  '.ipynb_checkpoints',
#  'Untitled2.ipynb']

# %%
#新增目錄
os.makedirs("test") #新增一個test的目錄
os.listdir(".") #顯示目錄
# Out:
# ['TCGA_Data',
#  'jupyterlab-slides.pdf',
#  'data',
#  'jupyterlab.md',
#  'lorenz.py',
#  'big.csv',
#  'Lorenz.ipynb',
#  'markdown_python.md',
#  'notebooks',
#  'test',
#  'Untitled1.ipynb',
#  'Untitled.ipynb',
#  '.ipynb_checkpoints',
#  'Untitled2.ipynb']

# %%
#移除目錄
os.rmdir("test") #刪除test目錄
os.listdir(".") #顯示目錄
# Out:
# ['TCGA_Data',
#  'jupyterlab-slides.pdf',
#  'data',
#  'jupyterlab.md',
#  'lorenz.py',
#  'big.csv',
#  'Lorenz.ipynb',
#  'markdown_python.md',
#  'notebooks',
#  'Untitled1.ipynb',
#  'Untitled.ipynb',
#  '.ipynb_checkpoints',
#  'Untitled2.ipynb']

# %% [markdown]
# # 檔案處理
# os套件有自己的檔案處理命令，而比較常用的是python內建的open
#
# * w = 可寫(預設建立檔案) 若檔案存在則會清除舊檔案
# * w+ = 可寫可讀(預設建立檔案) 若檔案存在則會清除舊檔案
# * r = 可讀
# * r+ = 可寫可讀 但寫入資料指向開頭
# * a = 可寫不能讀 寫入資料指向尾端
# * a+ = 可寫可讀 寫入資料指向尾端
# * b = 轉為2進位文件
# * ab+ = 2進位文件的讀寫 寫入資料指向尾端

# %% [markdown]
# # 新增檔案

# %%
a=open("a.txt","w") #新增檔案
a.write("This is a test1")
a.write("This is a test2\n")
a.write("This is a test3\n")
a.close() #關閉檔案

# %% [markdown]
# # 檢查檔案是否存在

# %%
os.path.isfile("a.txt") #檢查命名為a的檔案是否存在
# Out:
# True

# %% [markdown]
# # 讀取檔案

# %%
a=open("a.txt","r")
print(a.readline())
print(a.readline())
print(a.readline()) #多餘的命令，檔案只有2行
a.close()
# Out:
# This is a test1This is a test2
#
# This is a test3

# %%
a=open("a.txt","r")
print(a.readlines())  #一次讀取多行，與a.read()命令相同
a.close()
# Out:
# ['This is a test1This is a test2\n', 'This is a test3\n']

# %%
#加上檔案是否存在的判斷
if os.path.isfile("a.txt"):
    a=open("a.txt","r")
    print(a.readlines()) #一次讀取多行
    a.close()
else:
    print("檔案不存在") #當檔案不存在就顯示"檔案不存在"
# Out:
# ['This is a test1This is a test2\n', 'This is a test3\n']

# %% [markdown]
# # 附加檔案

# %%
a=open("a.txt", "a")
a.write("This is test4\n")
a.close()

# %%
a=open("a.txt","r")
print(a.readlines())
a.close()
# Out:
# ['This is a test1This is a test2\n', 'This is a test3\n', 'This is test4\n']

# %% [markdown]
# # 比較a與r+的不同
# * a寫在檔案的結尾
# * r+寫在檔案的開頭

# %%
a=open("a.txt","r+")
a.write("This is a test5\n")
a.close()

# %%
a=open("a.txt","r")
print(a.readlines())
a.close()
# Out:
# ['This is a test5\n', 'his is a test2\n', 'This is a test3\n', 'This is test4\n']

# %% [markdown]
# # 刪除檔案

# %%
if os.path.isfile("a.txt"):
    os.remove("a.txt") #刪除 a.txt檔案
    print("檔案刪除成功") # 當檔案刪除成功顯示"檔案刪除成功"
else:
    print("找不到檔案") #若檔案不存在"顯示找不到檔案"
print(os.path.isfile("a.txt"))
# Out:
# 檔案刪除成功
# False
