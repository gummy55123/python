# %% [markdown]
# # 函式(數)
# # 傳統的寫法

# %%
import math
radius = eval(input("請輸入圓的半徑：")) #把輸入的字串變成數學計算型態
print("圓的面積為：", radius * radius * math.pi)
# Out:
# 請輸入圓的半徑： 9
# 圓的面積為： 254.46900494077323

# %% [markdown]
# # 面積計算函示

# %%
import math
def circle_area(radius):
    area = radius * radius * math.pi
    return area

print(circle_area(10))
# Out:
# 314.1592653589793
